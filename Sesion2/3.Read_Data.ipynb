# %%
import pandas as pd
import sqlalchemy as db

# %%
#En terminal: ifconfig da la ip            ^^^^^^^^^^
engine=db.create_engine("mysql://root:root@10.0.0.207:3310/retail_db")
conn=engine.connect()

# %%
df_costumers=pd.read_sql_query("SELECT * FROM customers limit 10",con=conn)
df_costumers
# Out:
#    customer_id customer_fname customer_lname customer_email customer_password  \
# 0            1        Richard      Hernandez      XXXXXXXXX         XXXXXXXXX
# 1            2           Mary        Barrett      XXXXXXXXX         XXXXXXXXX
# 2            3            Ann          Smith      XXXXXXXXX         XXXXXXXXX
# 3            4           Mary          Jones      XXXXXXXXX         XXXXXXXXX
# 4            5         Robert         Hudson      XXXXXXXXX         XXXXXXXXX
# 5            6           Mary          Smith      XXXXXXXXX         XXXXXXXXX
# 6            7        Melissa         Wilcox      XXXXXXXXX         XXXXXXXXX
# 7            8          Megan          Smith      XXXXXXXXX         XXXXXXXXX
# 8            9           Mary          Perez      XXXXXXXXX         XXXXXXXXX
# 9           10        Melissa          Smith      XXXXXXXXX         XXXXXXXXX
#
#                customer_street customer_city customer_state customer_zipcode
# ...

# %%
df_orders=pd.read_sql_query("SELECT * FROM orders limit 10",con=conn)
df_orders
# Out:
#    order_id order_date  order_customer_id     order_status
# 0         1 2013-07-25              11599           CLOSED
# 1         2 2013-07-25                256  PENDING_PAYMENT
# 2         3 2013-07-25              12111         COMPLETE
# 3         4 2013-07-25               8827           CLOSED
# 4         5 2013-07-25              11318         COMPLETE
# 5         6 2013-07-25               7130         COMPLETE
# 6         7 2013-07-25               4530         COMPLETE
# 7         8 2013-07-25               2911       PROCESSING
# 8         9 2013-07-25               5657  PENDING_PAYMENT
# 9        10 2013-07-25               5648  PENDING_PAYMENT

# %%
#Mongo DB
from pymongo import MongoClient

# %%
def get_client_mongo():
    CONNECTION_STRING="mongodb+srv://soto729:<Poponigi123>@cluster0.xgtxs.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"
    CLIENT=MongoClient(CONNECTION_STRING)
    return CLIENT

# %%
client=get_client_mongo()
dbname=client['retail_db']
df_orders_dict=df_orders.to_dict("records")
dbname['orders'].insert_many(df_orders_dict)
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# Cell In[38], line 4
#       2 dbname=client['retail_db']
#       3 df_orders_dict=df_orders.to_dict("records")
# ----> 4 dbname['orders'].insert_many(df_orders_dict)
#
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/pymongo/_csot.py:108, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     106         with _TimeoutContext(timeout):
#     107             return func(self, *args, **kwargs)
# --> 108 return func(self, *args, **kwargs)
#
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/pymongo/collection.py:742, in Collection.insert_many(self, documents, ordered, bypass_document_validation, session, comment)
#     740 blk = _Bulk(self, ordered, bypass_document_validation, comment=comment)
#     741 blk.ops = list(gen())
# --> 742 blk.execute(write_concern, session, _Op.INSERT)
# ...

# %%
mongo_orders=dbname['orders'].find({})
mongo_orders

# %%
df_orders=pd.DataFrame(mongo_orders)
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 df_orders=pd.DataFrame(mongo_orders)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/frame.py:843, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     841         data = np.asarray(data)
#     842     else:
# --> 843         data = list(data)
#     844 if len(data) > 0:
#     845     if is_dataclass(data[0]):
#
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/pymongo/cursor.py:1243, in Cursor.next(self)
#    1241 if self.__empty:
#    1242     raise StopIteration
# -> 1243 if len(self.__data) or self._refresh():
#    1244     return self.__data.popleft()
#    1245 else:
#
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/pymongo/cursor.py:1160, in Cursor._refresh(self)
#    1138         raise InvalidOperation(
# ...
